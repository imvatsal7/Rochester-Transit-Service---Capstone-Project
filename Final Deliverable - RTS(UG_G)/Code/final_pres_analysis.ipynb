# %%
import pandas 
import pandas as pd

data = pandas.ExcelFile("Master_Scheduled_Days_Off.xlsx")
df = pd.read_excel("Master_Scheduled_Days_Off.xlsx")

df_scheduled=df.set_index('Operator_ID')
df_scheduled.head()
# Out:
#             Effective_On No_Longer_Effective_After Pick_Name Seniority_Date  \
# Operator_ID
# 1             2016-04-04                2016-06-26   APR2016     06-20-1974
# 2             2016-04-04                2016-06-26   APR2016     08-22-1974
# 3             2016-04-04                2016-06-26   APR2016     06-22-1977
# 5             2016-04-04                2016-06-26   APR2016     08-03-1977
# 6             2016-04-04                2016-06-26   APR2016     02-04-1980
#
#               Sun  Mon  Tue  Wed  Thu  Fri   Sat Type_Work
# Operator_ID
# 1             OFF  NaN  NaN  NaN  NaN  NaN   OFF   REGULAR
# 2             OFF  NaN  NaN  NaN  NaN  NaN   OFF        XB
# 3             OFF  NaN  NaN  NaN  NaN  NaN   OFF   REGULAR
# 5             OFF  NaN  NaN  NaN  NaN  NaN   OFF   REGULAR
# 6             OFF  NaN  NaN  NaN  NaN  NaN   OFF        XB

# %%
df3 = pd.read_excel("Master_Absence_Data.xlsx")

df3=df3.set_index('Operator_ID')
df_absence=df3.drop(columns=['Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9'])
df_absence.head()
# Out:
#             Absence_Type  From_Date From_Time    To_Date To_Time
# Operator_ID
# 3                 Absent 2016-04-01      0:00 2016-04-01   25:00
# 6                Excused 2016-04-01     13:22 2016-04-01   16:34
# 10              Vacation 2016-04-01      0:00 2016-04-01   25:00
# 11               Medical 2016-04-01      0:00 2016-04-01   25:00
# 27               Medical 2016-04-01      0:00 2016-04-01   25:00

# %%
df2 = pd.read_excel("Master_Accident_Data.xlsx")

df_acc=df2.set_index('Operator_ID')
df_acc.head()
# Out:
#                         accdate            AccTypeCodeDescr  \
# Operator_ID
# 1           2014-09-29 15:07:00  Collisions w/Other Objects
# 1           2015-03-18 15:29:00             Vehicle Passing
# 1           2015-12-08 08:59:00             Vehicle Passing
# 1           2016-02-19 13:16:00             Vehicle Passing
# 1           2016-04-20 11:46:00             Vehicle Passing
#
#                                          AccSubTypeCodeDescr  \
# Operator_ID
# 1                     Fixed object (lamp posts, poles, etc.)
# 1             Vehicle cuts in and scrapes RGRTA on left side
# 1             Vehicle cuts in and scrapes RGRTA on left side
# 1             Vehicle cuts in and scrapes RGRTA on left side
# 1            Vehicle cuts in and scrapes RGRTA on right side
#
#                                 acctype BAITFISH Code FileNumber  \
# Operator_ID
# 1            04 - MVA with Fixed Object  Fixed Object    14-1043
# ...

# %%
for col in df2.columns: 
    print(col)
# Out:
# accdate
# Operator_ID
# AccTypeCodeDescr
# AccSubTypeCodeDescr
# acctype
# BAITFISH Code
# FileNumber
# AccPreventable
# Retraining
# RetrainingDate
# vehbusno
# vehmake
# vehyear
# VehNoOccupants
# Drv_Age
# CoDrvSex
# Roadway
# RoadwayLightConditions
# RoadwayWeather
# RoadwaySurface
# LocAddr1
# Addr_Type
# Neighborhood

# %%
rslt_df = df_acc[df_acc['AccPreventable']=='Preventable']
rslt_df
# Out:
#                         accdate                          AccTypeCodeDescr  \
# Operator_ID
# 1           2014-09-29 15:07:00                Collisions w/Other Objects
# 1           2017-01-03 10:40:00          RGRTA Passing Stationary Vehicle
# 2           2019-01-22 07:55:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 3           2015-09-22 06:45:00                Collisions w/Other Objects
# 4           2015-04-20 13:14:00                Collisions w/Fixed Objects
# 8           2015-12-01 11:15:00                      Pedestrian collision
# 9           2016-09-16 07:10:00            Vehicle Approaching From Angle
# 10          2015-02-06 14:50:00                Collisions w/Fixed Objects
# 11          2014-10-17 19:24:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 12          2016-10-03 18:02:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 12          2018-03-19 16:58:00                Collisions w/Fixed Objects
# ...

# %%
top=rslt_df

ss=top.index
ls=ss.value_counts()
ds=ls.to_dict()
ds
dds=ds
# print(dds.values())
vv=dds.values()
import collections
counter=dict(collections.Counter(vv))
# print(counter)
plt.figure(figsize=(15,5))
ax = plt.axes()
ax.set_xticks(list(counter.keys()))
plt.xlabel('accidents counts')
plt.ylabel('drivers counts')
lld=list(counter.values())
import statistics



dsm=statistics.median(lld)
print(counter)
plt.bar(list(counter.keys()), list(counter.values()), color='grey')
# plt.axvline(dsm, color='k', linestyle='dashed', linewidth=1)
plt.show()
# Out:
# {11: 1, 6: 2, 5: 12, 4: 18, 3: 39, 2: 79, 1: 206}

# %%
plt.figure(figsize=(15,5))
ax = plt.axes()
ax.set_xticks(list(counter.keys()))
plt.xlabel('accidents counts')
plt.ylabel('drivers counts')
lld=list(counter.values())
import statistics



dsm=statistics.median(lld)
print(counter)
plt.title('preventable accidents frequency table')
plt.bar(list(counter.keys()), list(counter.values()), color='navy')
plt.show()
# Out:
# {11: 1, 6: 2, 5: 12, 4: 18, 3: 39, 2: 79, 1: 206}

# %%
ds
# Out:
# {83: 11,
#  238: 6,
#  273: 6,
#  275: 5,
#  506: 5,
#  487: 5,
#  197: 5,
#  480: 5,
#  388: 5,
#  323: 5,
#  493: 5,
#  66: 5,
#  218: 5,
#  214: 5,
#  61: 5,
#  292: 4,
#  473: 4,
#  324: 4,
#  375: 4,
#  153: 4,
#  185: 4,
#  252: 4,
#  128: 4,
#  62: 4,
#  205: 4,
#  331: 4,
#  470: 4,
#  249: 4,
#  237: 4,
#  32: 4,
#  342: 4,
#  298: 4,
#  241: 4,
#  297: 3,
#  402: 3,
#  158: 3,
#  285: 3,
#  125: 3,
#  282: 3,
#  456: 3,
#  455: 3,
#  357: 3,
#  472: 3,
#  182: 3,
#  256: 3,
#  222: 3,
#  239: 3,
#  240: 3,
#  178: 3,
#  245: 3,
#  299: 3,
#  85: 3,
#  361: 3,
#  22: 3,
#  364: 3,
#  37: 3,
#  337: 3,
#  515: 3,
#  332: 3,
#  511: 3,
#  59: 3,
#  503: 3,
#  300: 3,
#  76: 3,
#  84: 3,
#  73: 3,
#  318: 3,
#  124: 3,
#  315: 3,
#  119: 3,
#  319: 3,
#  312: 3,
#  321: 2,
#  336: 2,
#  248: 2,
#  290: 2,
#  289: 2,
#  305: 2,
#  251: 2,
#  308: 2,
#  284: 2,
#  329: 2,
#  327: 2,
#  261: 2,
#  326: 2,
#  270: 2,
#  272: 2,
#  171: 2,
#  229: 2,
#  115: 2,
#  105: 2,
# ...

# %%
ds
# Out:
# {83: 11,
#  238: 6,
#  273: 6,
#  275: 5,
#  506: 5,
#  487: 5,
#  197: 5,
#  480: 5,
#  388: 5,
#  323: 5,
#  493: 5,
#  66: 5,
#  218: 5,
#  214: 5,
#  61: 5,
#  292: 4,
#  473: 4,
#  324: 4,
#  375: 4,
#  153: 4,
#  185: 4,
#  252: 4,
#  128: 4,
#  62: 4,
#  205: 4,
#  331: 4,
#  470: 4,
#  249: 4,
#  237: 4,
#  32: 4,
#  342: 4,
#  298: 4,
#  241: 4,
#  297: 3,
#  402: 3,
#  158: 3,
#  285: 3,
#  125: 3,
#  282: 3,
#  456: 3,
#  455: 3,
#  357: 3,
#  472: 3,
#  182: 3,
#  256: 3,
#  222: 3,
#  239: 3,
#  240: 3,
#  178: 3,
#  245: 3,
#  299: 3,
#  85: 3,
#  361: 3,
#  22: 3,
#  364: 3,
#  37: 3,
#  337: 3,
#  515: 3,
#  332: 3,
#  511: 3,
#  59: 3,
#  503: 3,
#  300: 3,
#  76: 3,
#  84: 3,
#  73: 3,
#  318: 3,
#  124: 3,
#  315: 3,
#  119: 3,
#  319: 3,
#  312: 3,
#  321: 2,
#  336: 2,
#  248: 2,
#  290: 2,
#  289: 2,
#  305: 2,
#  251: 2,
#  308: 2,
#  284: 2,
#  329: 2,
#  327: 2,
#  261: 2,
#  326: 2,
#  270: 2,
#  272: 2,
#  171: 2,
#  229: 2,
#  115: 2,
#  105: 2,
# ...

# %%
df3
# Out:
#                Absence_Type  From_Date From_Time    To_Date To_Time  \
# Operator_ID
# 3                    Absent 2016-04-01      0:00 2016-04-01   25:00
# 6                   Excused 2016-04-01     13:22 2016-04-01   16:34
# 10                 Vacation 2016-04-01      0:00 2016-04-01   25:00
# 11                  Medical 2016-04-01      0:00 2016-04-01   25:00
# 27                  Medical 2016-04-01      0:00 2016-04-01   25:00
# 34                   Absent 2016-04-01      0:00 2016-04-01   25:00
# 39                   Absent 2016-04-01      0:00 2016-04-01   25:00
# 59                   Absent 2016-04-01      0:00 2016-04-01   25:00
# 62                 Vacation 2016-04-01      0:00 2016-04-01   25:00
# 82                  Excused 2016-04-01      0:00 2016-04-01   25:00
# 93                   Absent 2016-04-01      0:00 2016-04-01   25:00
# 98           Worked Day Off 2016-04-01      0:00 2016-04-01   25:00
# 103                  Absent 2016-04-01      0:00 2016-04-01   25:00
# ...

# %%
cd=df[['Effective_On','No_Longer_Effective_After']]
cd
dsd=df2[['accdate']]
dsd.head()
dsd3=df3[["Absence_Type",'From_Date','To_Date']]
dday_count=dsd3['To_Date']-dsd3['From_Date']
dday_count_num=str_s(dday_count)
dsd3['absence_count']=dday_count

dsd3
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                Absence_Type  From_Date    To_Date absence_count
# Operator_ID
# 3                    Absent 2016-04-01 2016-04-01        0 days
# 6                   Excused 2016-04-01 2016-04-01        0 days
# 10                 Vacation 2016-04-01 2016-04-01        0 days
# 11                  Medical 2016-04-01 2016-04-01        0 days
# 27                  Medical 2016-04-01 2016-04-01        0 days
# 34                   Absent 2016-04-01 2016-04-01        0 days
# 39                   Absent 2016-04-01 2016-04-01        0 days
# 59                   Absent 2016-04-01 2016-04-01        0 days
# ...

# %%
dsd
# Out:
#                  accdate
# 0    2014-09-29 15:07:00
# 1    2015-03-18 15:29:00
# 2    2015-12-08 08:59:00
# 3    2016-02-19 13:16:00
# 4    2016-04-20 11:46:00
# 5    2017-01-03 10:40:00
# 6    2018-06-11 11:04:00
# 7    2018-09-21 08:07:00
# 8    2014-09-19 15:10:00
# 9    2015-03-14 10:10:00
# 10   2017-05-05 07:22:00
# 11   2019-01-22 07:55:00
# 12   2015-09-22 06:45:00
# 13   2015-03-24 16:40:00
# 14   2015-04-20 13:14:00
# 15   2015-11-06 17:26:00
# 16   2017-09-27 09:44:00
# 17   2015-10-15 10:00:00
# 18   2014-12-12 16:45:00
# 19   2016-10-04 10:22:00
# 20   2015-07-13 13:22:00
# 21   2015-12-01 11:15:00
# 22   2015-01-21 09:24:00
# 23   2016-09-16 07:10:00
# 24   2015-02-06 14:50:00
# 25   2015-02-09 18:48:00
# 26   2016-03-04 18:34:00
# 27   2016-12-07 17:14:00
# 28   2014-10-17 19:24:00
# 29   2014-11-18 07:27:00
# ...                  ...
# 1284 2018-02-20 23:42:00
# 1285 2019-02-01 18:15:00
# 1286 2019-02-25 21:00:00
# 1287 2017-02-08 20:01:00
# 1288 2017-02-13 21:10:00
# ...

# %%
l2=cd.loc[1]
ll2=df_acc.loc[1]
lll2=df_absence.loc[1]
result2 = ll2.join(lll2, how='outer')
result2
lmun2=result2['accdate']-result2['From_Date']


lsl2=[]
for s in lmun2:
    str_ss=str(s)
    splited = str_ss.split(" ")
    lsl2.append(int(splited[0]))
    

result2['count']=lsl2
result2
# Out:
#                         accdate                      AccTypeCodeDescr  \
# Operator_ID
# 1           2014-09-29 15:07:00            Collisions w/Other Objects
# 1           2014-09-29 15:07:00            Collisions w/Other Objects
# 1           2014-09-29 15:07:00            Collisions w/Other Objects
# 1           2014-09-29 15:07:00            Collisions w/Other Objects
# 1           2014-09-29 15:07:00            Collisions w/Other Objects
# 1           2014-09-29 15:07:00            Collisions w/Other Objects
# 1           2014-09-29 15:07:00            Collisions w/Other Objects
# 1           2014-09-29 15:07:00            Collisions w/Other Objects
# 1           2014-09-29 15:07:00            Collisions w/Other Objects
# 1           2014-09-29 15:07:00            Collisions w/Other Objects
# 1           2014-09-29 15:07:00            Collisions w/Other Objects
# 1           2014-09-29 15:07:00            Collisions w/Other Objects
# ...

# %%
ds
# Out:
# {83: 11,
#  238: 6,
#  273: 6,
#  275: 5,
#  506: 5,
#  487: 5,
#  197: 5,
#  480: 5,
#  388: 5,
#  323: 5,
#  493: 5,
#  66: 5,
#  218: 5,
#  214: 5,
#  61: 5,
#  292: 4,
#  473: 4,
#  324: 4,
#  375: 4,
#  153: 4,
#  185: 4,
#  252: 4,
#  128: 4,
#  62: 4,
#  205: 4,
#  331: 4,
#  470: 4,
#  249: 4,
#  237: 4,
#  32: 4,
#  342: 4,
#  298: 4,
#  241: 4,
#  297: 3,
#  402: 3,
#  158: 3,
#  285: 3,
#  125: 3,
#  282: 3,
#  456: 3,
#  455: 3,
#  357: 3,
#  472: 3,
#  182: 3,
#  256: 3,
#  222: 3,
#  239: 3,
#  240: 3,
#  178: 3,
#  245: 3,
#  299: 3,
#  85: 3,
#  361: 3,
#  22: 3,
#  364: 3,
#  37: 3,
#  337: 3,
#  515: 3,
#  332: 3,
#  511: 3,
#  59: 3,
#  503: 3,
#  300: 3,
#  76: 3,
#  84: 3,
#  73: 3,
#  318: 3,
#  124: 3,
#  315: 3,
#  119: 3,
#  319: 3,
#  312: 3,
#  321: 2,
#  336: 2,
#  248: 2,
#  290: 2,
#  289: 2,
#  305: 2,
#  251: 2,
#  308: 2,
#  284: 2,
#  329: 2,
#  327: 2,
#  261: 2,
#  326: 2,
#  270: 2,
#  272: 2,
#  171: 2,
#  229: 2,
#  115: 2,
#  105: 2,
# ...

# %%
acc_more_list1=list(ds.keys())
print(acc_more_list1)
print(len(acc_more_list1))
# Out:
# [83, 238, 273, 275, 506, 487, 197, 480, 388, 323, 493, 66, 218, 214, 61, 292, 473, 324, 375, 153, 185, 252, 128, 62, 205, 331, 470, 249, 237, 32, 342, 298, 241, 297, 402, 158, 285, 125, 282, 456, 455, 357, 472, 182, 256, 222, 239, 240, 178, 245, 299, 85, 361, 22, 364, 37, 337, 515, 332, 511, 59, 503, 300, 76, 84, 73, 318, 124, 315, 119, 319, 312, 321, 336, 248, 290, 289, 305, 251, 308, 284, 329, 327, 261, 326, 270, 272, 171, 229, 115, 105, 103, 101, 98, 97, 87, 79, 71, 65, 64, 56, 55, 53, 39, 30, 23, 12, 114, 118, 213, 131, 202, 192, 186, 184, 176, 172, 165, 164, 162, 161, 154, 150, 148, 146, 141, 135, 134, 355, 1, 389, 450, 393, 438, 478, 507, 443, 504, 383, 485, 381, 513, 411, 471, 448, 512, 412, 458, 464, 363, 359, 95, 120, 90, 92, 481, 482, 116, 488, 102, 492, 113, 107, 490, 486, 100, 489, 483, 358, 121, 122, 156, 155, 466, 151, 467, 149, 468, 469, 144, 142, 140, 139, 137, 474, 475, 132, 476, 477, 127, 126, 494, 479, 123, 88, 80, 86, 521, 516, 38, 517, 518, 519, 29, 28, 27, 26, 2
# ...

# %%
def str_s(lu):
    
    ld=[]
    for s in lmunzz:
                str_ss=str(s)
                splited = str_ss.split(" ")
                try:
                    ld.append(int(splited[0]))
                except:
                    ld.append(0)
    return ld

# %%
dsd3
# Out:
#                Absence_Type  From_Date
# Operator_ID
# 3                    Absent 2016-04-01
# 6                   Excused 2016-04-01
# 10                 Vacation 2016-04-01
# 11                  Medical 2016-04-01
# 27                  Medical 2016-04-01
# 34                   Absent 2016-04-01
# 39                   Absent 2016-04-01
# 59                   Absent 2016-04-01
# 62                 Vacation 2016-04-01
# 82                  Excused 2016-04-01
# 93                   Absent 2016-04-01
# 98           Worked Day Off 2016-04-01
# 103                  Absent 2016-04-01
# 130                 Holiday 2016-04-01
# 132                 Medical 2016-04-01
# 149                  Absent 2016-04-01
# 153                 Excused 2016-04-01
# 155                  Absent 2016-04-01
# 180                  Absent 2016-04-01
# 182                  Absent 2016-04-01
# 190                  Absent 2016-04-01
# 207                 Medical 2016-04-01
# 210                 Excused 2016-04-01
# ...

# %%
dsd3
# Out:
#                Absence_Type  From_Date
# Operator_ID
# 3                    Absent 2016-04-01
# 6                   Excused 2016-04-01
# 10                 Vacation 2016-04-01
# 11                  Medical 2016-04-01
# 27                  Medical 2016-04-01
# 34                   Absent 2016-04-01
# 39                   Absent 2016-04-01
# 59                   Absent 2016-04-01
# 62                 Vacation 2016-04-01
# 82                  Excused 2016-04-01
# 93                   Absent 2016-04-01
# 98           Worked Day Off 2016-04-01
# 103                  Absent 2016-04-01
# 130                 Holiday 2016-04-01
# 132                 Medical 2016-04-01
# 149                  Absent 2016-04-01
# 153                 Excused 2016-04-01
# 155                  Absent 2016-04-01
# 180                  Absent 2016-04-01
# 182                  Absent 2016-04-01
# 190                  Absent 2016-04-01
# 207                 Medical 2016-04-01
# 210                 Excused 2016-04-01
# ...

# %%
resultzz
# Out:
#                         accdate                             AccTypeCodeDescr  \
# Operator_ID
# 359         2017-09-07 05:17:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 359         2017-09-07 05:17:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 359         2017-09-07 05:17:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 359         2017-09-07 05:17:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 359         2017-09-07 05:17:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 359         2017-09-07 05:17:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 359         2017-09-07 05:17:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 359         2017-09-07 05:17:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 359         2017-09-07 05:17:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 359         2017-09-07 05:17:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 359         2017-09-07 05:17:00     Collisions w/RGRTA vehicles (Bus to Bus)
# ...

# %%
fi
# Out:
#                         accdate                             AccTypeCodeDescr  \
# Operator_ID
# 83          2016-07-19 14:55:00                              Vehicle Passing
# 83          2016-07-19 14:55:00                              Vehicle Passing
# 83          2016-07-26 08:33:00         Collisions with other motor vehicles
# 83          2016-07-26 08:33:00         Collisions with other motor vehicles
# 83          2018-03-26 14:41:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 83          2018-03-26 14:41:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 83          2018-06-27 13:58:00                   Collisions w/Fixed Objects
# 83          2018-06-29 15:01:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 83          2018-12-04 07:55:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 83          2018-12-04 07:55:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 83          2018-12-04 07:55:00     Collisions w/RGRTA vehicles (Bus to Bus)
# ...

# %%
fi=pd.DataFrame()
for i in acc_more_list1:
            try:
                    one_acc=rslt_df.loc[i]
                    abs_two=dsd3.loc[i]
                    resultzz = one_acc.join(abs_two, how='outer')
            except:
                    print(i)
            
                
            

            lmunzz=resultzz['accdate']-resultzz['From_Date']
            lmk=resultzz['From_Date']-resultzz['To_Date']
            

            ls=str_s(lmunzz)
            lsdd=str_s(lmk)

            resultzz['count']=ls
            
            resultzz['count_ab']=lsdd
            

            fi88 = resultzz[(resultzz['count'] > 0) & (resultzz['count'] < 31) ]
            fi=fi.append(fi88)
# Out:
# 506
# 487
# 480
# 493
# 473
# 470
# 456
# 455
# 472
# 515
# 511
# 503
# 284
# 450
# 438
# 478
# 507
# 443
# 504
# 485
# 513
# 471
# 448
# 512
# 458
# 464
# 95
# 120
# 90
# 92
# 481
# 482
# 116
# 488
# 102
# 492
# 113
# 107
# 490
# 486
# 100
# 489
# 483
# 358
# 121
# 122
# 156
# 155
# 466
# 151
# 467
# 149
# 468
# 469
# 144
# 142
# 140
# 139
# 137
# 474
# 475
# 132
# 476
# 477
# 127
# 126
# 494
# 479
# 123
# 88
# 80
# 86
# 521
# 516
# 38
# 517
# 518
# 519
# 29
# 28
# 27
# 26
# 24
# 520
# 21
# 495
# 18
# 16
# 13
# 522
# 11
# 10
# 9
# 8
# 4
# 3
# 2
# 41
# 42
# 45
# 46
# 496
# 497
# 81
# 462
# 498
# 499
# 75
# 74
# 500
# 72
# 501
# 70
# 69
# 502
# 505
# 63
# 509
# 60
# 510
# 54
# 514
# 52
# 49
# 463
# 454
# 460
# 302
# 390
# 391
# 397
# 398
# 288
# 287
# 400
# 403
# 283
# 404
# 281
# 278
# 405
# 406
# 523
# 271
# 410
# 267
# 266
# 259
# 258
# 255
# 254
# 387
# 304
# 163
# 385
# 356
# 360
# 354
# 352
# 350
# 345
# 365
# 366
# 335
# 367
# 370
# 371
# 372
# 373
# 374
# 377
# 378
# 380
# ...

# %%
fi
# Out:
#                         accdate                             AccTypeCodeDescr  \
# Operator_ID
# 83          2016-07-19 14:55:00                              Vehicle Passing
# 83          2016-07-19 14:55:00                              Vehicle Passing
# 83          2016-07-26 08:33:00         Collisions with other motor vehicles
# 83          2016-07-26 08:33:00         Collisions with other motor vehicles
# 83          2018-03-26 14:41:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 83          2018-03-26 14:41:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 83          2018-06-27 13:58:00                   Collisions w/Fixed Objects
# 83          2018-06-29 15:01:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 83          2018-12-04 07:55:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 83          2018-12-04 07:55:00     Collisions w/RGRTA vehicles (Bus to Bus)
# 83          2018-12-04 07:55:00     Collisions w/RGRTA vehicles (Bus to Bus)
# ...

# %%
df_acc=df_acc[df_acc['AccPreventable']=='Preventable']
df_acc
# Out:
#                         accdate                          AccTypeCodeDescr  \
# Operator_ID
# 1           2014-09-29 15:07:00                Collisions w/Other Objects
# 1           2017-01-03 10:40:00          RGRTA Passing Stationary Vehicle
# 2           2019-01-22 07:55:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 3           2015-09-22 06:45:00                Collisions w/Other Objects
# 4           2015-04-20 13:14:00                Collisions w/Fixed Objects
# 8           2015-12-01 11:15:00                      Pedestrian collision
# 9           2016-09-16 07:10:00            Vehicle Approaching From Angle
# 10          2015-02-06 14:50:00                Collisions w/Fixed Objects
# 11          2014-10-17 19:24:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 12          2016-10-03 18:02:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 12          2018-03-19 16:58:00                Collisions w/Fixed Objects
# ...

# %%
import numpy as np
fi_less7 = fi[(fi['count'] > 0) & (fi['count'] < 8) ]
fi_less7=fi_less7[fi_less7['AccPreventable']=='Preventable']
fi_less7
fi_less7['test_bool'] = np.where(fi_less7['absence_count']=='0days', 'green', 'red')
fi_less7
# Out:
#                         accdate                          AccTypeCodeDescr  \
# Operator_ID
# 83          2016-07-26 08:33:00      Collisions with other motor vehicles
# 83          2019-01-11 15:22:00          RGRTA Passing Stationary Vehicle
# 83          2019-01-11 15:22:00          RGRTA Passing Stationary Vehicle
# 238         2018-11-13 15:38:00          RGRTA Passing Stationary Vehicle
# 273         2018-04-10 17:12:00                Collisions w/Fixed Objects
# 273         2018-04-17 14:51:00                Collisions w/Fixed Objects
# 273         2018-04-17 14:51:00                Collisions w/Fixed Objects
# 273         2018-06-12 05:29:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 273         2018-06-12 05:29:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 275         2018-06-25 11:18:00      Collisions with other motor vehicles
# 275         2018-06-25 11:18:00      Collisions with other motor vehicles
# ...

# %%
city_count_less7
# Out:
# 7    30
# 4    27
# 6    26
# 1    21
# 2    20
# 3    14
# 5    12
# Name: count, dtype: int64

# %%
city_count_less7  = fi_less7['count'].value_counts()

plt.figure(figsize=(20,10))
sns.barplot(, alpha=0.8,color="orange",hue='test_bool')


plt.title('absence day count before preventable accidents happend')
plt.ylabel('drivers count', fontsize=12)
plt.xlabel('days counts', fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-315d599e69de> in <module>
#       2
#       3 plt.figure(figsize=(20,10))
# ----> 4 sns.barplot(city_count_less7, alpha=0.8,color="orange",hue='test_bool')
#       5
#       6
#
# /anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# ...

# %%
fi_less15 = fi[(fi['count'] > 0) & (fi['count'] < 15) ]

# %%
fi_less15
# Out:
#                         accdate                          AccTypeCodeDescr  \
# Operator_ID
# 83          2016-07-19 14:55:00                           Vehicle Passing
# 83          2016-07-26 08:33:00      Collisions with other motor vehicles
# 83          2018-06-27 13:58:00                Collisions w/Fixed Objects
# 83          2018-06-29 15:01:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 83          2019-01-11 15:22:00          RGRTA Passing Stationary Vehicle
# 83          2019-01-11 15:22:00          RGRTA Passing Stationary Vehicle
# 238         2018-11-13 15:38:00          RGRTA Passing Stationary Vehicle
# 238         2018-11-13 15:38:00          RGRTA Passing Stationary Vehicle
# 273         2018-04-10 17:12:00                Collisions w/Fixed Objects
# 273         2018-04-17 14:51:00                Collisions w/Fixed Objects
# 273         2018-04-17 14:51:00                Collisions w/Fixed Objects
# ...

# %%
city_count_less15
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-069a226c190f> in <module>
# ----> 1 city_count_less15
#
# NameError: name 'city_count_less15' is not defined

# %%
ab=fi_less15[fi_less15['count']==14]
ab
# Out:
#                         accdate                          AccTypeCodeDescr  \
# Operator_ID
# 83          2018-06-29 15:01:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 323         2016-05-03 14:30:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 323         2016-05-03 14:30:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 66          2019-05-17 17:00:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 61          2019-04-22 15:38:00                Collisions w/Fixed Objects
# 153         2019-06-03 17:22:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 185         2017-01-04 06:55:00                Collisions w/Other Objects
# 252         2016-08-12 17:20:00                      Pedestrian collision
# 128         2018-07-06 13:30:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 62          2019-07-01 04:51:00                Collisions w/Fixed Objects
# 331         2018-12-30 20:15:00      Thrown by movement of RGRTA stopping
# ...

# %%
import seaborn as sns
city_count_less15  = fi_less15['count'].value_counts()

plt.figure(figsize=(20,10))
sns.barplot(city_count_less15.index, city_count_less15.values, alpha=0.8,color="orange")


plt.title('absence day count before preventable accidents happend')
plt.ylabel('drivers count', fontsize=12)
plt.xlabel('days counts', fontsize=12)
plt.show()

# %%
df2.head()

dfg = df2[['accdate']].groupby('accdate').count()

retain_count_Y  = df_acc[df_acc['Retraining']=='Y']
retain_count_N = df_acc[df_acc['Retraining']=='N']

retain_count_Y#631
retain_count_N#5
df_acc #636
# Out:
#                         accdate                          AccTypeCodeDescr  \
# Operator_ID
# 1           2014-09-29 15:07:00                Collisions w/Other Objects
# 1           2017-01-03 10:40:00          RGRTA Passing Stationary Vehicle
# 2           2019-01-22 07:55:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 3           2015-09-22 06:45:00                Collisions w/Other Objects
# 4           2015-04-20 13:14:00                Collisions w/Fixed Objects
# 8           2015-12-01 11:15:00                      Pedestrian collision
# 9           2016-09-16 07:10:00            Vehicle Approaching From Angle
# 10          2015-02-06 14:50:00                Collisions w/Fixed Objects
# 11          2014-10-17 19:24:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 12          2016-10-03 18:02:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 12          2018-03-19 16:58:00                Collisions w/Fixed Objects
# ...

# %%
nonp  = df2[df2['AccPreventable']=='Preventable']
prev = df2[df2['AccPreventable']=='Non-Preventable']

dfg_NP = nonp[['accdate']].groupby('accdate').count()
month_df_NP = dfg_NP.resample('M').size()
dfg_P = prev[['accdate']].groupby('accdate').count()
month_df_P = dfg_P.resample('M').size()
plt.figure(figsize=(15,6))
month_df_NP.plot(label='Total,  non-preventaable accidents per month', color='green')
month_df_P.plot(label='Total,  preventable-accidents per month', color='sandybrown')
plt.legend()

# %%
prev
# Out:
#                  accdate  Operator_ID  \
# 0    2014-09-29 15:07:00            1
# 5    2017-01-03 10:40:00            1
# 11   2019-01-22 07:55:00            2
# 12   2015-09-22 06:45:00            3
# 14   2015-04-20 13:14:00            4
# 21   2015-12-01 11:15:00            8
# 23   2016-09-16 07:10:00            9
# 24   2015-02-06 14:50:00           10
# 28   2014-10-17 19:24:00           11
# 33   2016-10-03 18:02:00           12
# 37   2018-03-19 16:58:00           12
# 40   2018-04-20 14:11:00           13
# 45   2015-04-29 07:56:00           16
# 49   2017-07-31 10:05:00           18
# 54   2015-06-19 23:26:00           21
# 57   2014-08-04 11:57:00           22
# 59   2015-03-25 23:08:00           22
# 61   2019-07-23 23:29:00           22
# 63   2016-10-08 12:35:00           23
# 64   2017-03-23 15:45:00           23
# 66   2016-08-23 12:30:00           24
# 70   2018-03-20 15:24:00           26
# 74   2018-12-06 18:45:00           27
# ...

# %%
prev = df2[df2['AccPreventable']=='Preventable']
# prev[prev['accdate']]

start_date = '2015-01-01'
end_date = '2015-03-30'

mask = (prev['accdate'] > start_date) & (prev['accdate'] <= end_date)
df_mask = prev.loc[mask]
df_mask
#54
sns.catplot(x='RoadwaySurface',kind="count",hue="AccPreventable",data=df_mask)

# %%
ax=sns.catplot(x='Roadway',kind="count",hue="AccPreventable",data=df_mask)

# %%
sns.catplot(x='RoadwayWeather',kind="count",hue="AccPreventable",data=df_mask)

# %%
retain_count_N
retain_count_Y

dfg_N = retain_count_N[['accdate']].groupby('accdate').count()
month_df_N = dfg_N.resample('M').size()
dfg_Y = retain_count_Y[['accdate']].groupby('accdate').count()
month_df_Y = dfg_Y.resample('M').size()
plt.figure(figsize=(15,6))
month_df_N.plot(label='Total,  accidents per month',color='green')
month_df_Y.plot(label='Total,  accidents per month', color='sandybrown')

plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-149-9dfb4d14a5ef> in <module>
# ----> 1 retain_count_N
#       2 retain_count_Y
#       3
#       4 dfg_N = retain_count_N[['accdate']].groupby('accdate').count()
#       5 month_df_N = dfg_N.resample('M').size()
#
# NameError: name 'retain_count_N' is not defined

# %%
fi_less22 = fi[(fi['count'] > 0) & (fi['count'] < 22) ]
city_count_less22  = fi_less22['count'].value_counts()

plt.figure(figsize=(20,10))
sns.barplot(city_count_less22.index, city_count_less22.values, alpha=0.8,color="grey")


plt.title('absence day count before preventable accidents happend')
plt.ylabel('drivers count', fontsize=12)
plt.xlabel('days counts', fontsize=12)
plt.show()

# %%
fi
# df_acc[df_acc['AccPreventable']=='Preventable']
result=fi[fi['AccPreventable']=='Preventable']
# absence 和 preventable accident隔《= 30 天
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-8ab32b3509d7> in <module>
# ----> 1 fi
#       2 # df_acc[df_acc['AccPreventable']=='Preventable']
#       3 result=fi[fi['AccPreventable']=='Preventable']
#       4 # absence 和 preventable accident隔《= 30 天
#       5 result
#
# NameError: name 'fi' is not defined

# %%
print(result['Absence_Type'].value_counts())
result['Absence_Type'].value_counts().plot(kind='barh')
# Out:
# Excused           976
# Absent            428
# Vacation          140
# Worked Day Off     97
# Medical            71
# Late to Work       54
# Holiday            45
# Name: Absence_Type, dtype: int64

# %%
ssl=result.reset_index()
# ssl.plot(x='index', y='A')
plt.figure(figsize=(600,100))
ssl['Operator_ID'].value_counts().plot(kind='bar')

# %%
import seaborn as sns


fi_less30 = fi[(fi['count'] > 0) & (fi['count'] < 30) ]
city_count_less30  = fi_less30['count'].value_counts()

plt.figure(figsize=(20,10))
sns.barplot(city_count_less30.index, city_count_less30.values, alpha=0.8,color="orange")


plt.title('absence day count before preventable accidents happend')
plt.ylabel('drivers count', fontsize=12)
plt.xlabel('days counts', fontsize=12)
plt.show()
city_count  = result['count'].value_counts()

plt.figure(figsize=(20,10))
sns.barplot(city_count.index, city_count.values, alpha=0.8,color="orange")


plt.title('absence day count before preventable accidents happend')
plt.ylabel('drivers count', fontsize=12)
plt.xlabel('days counts', fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-133-1ee46b7b26ad> in <module>
#      13 plt.xlabel('days counts', fontsize=12)
#      14 plt.show()
# ---> 15 city_count  = result['count'].value_counts()
#      16
#      17 plt.figure(figsize=(20,10))
#
# NameError: name 'result' is not defined

# %%
rslt_df
# Out:
#                         accdate                          AccTypeCodeDescr  \
# Operator_ID
# 1           2014-09-29 15:07:00                Collisions w/Other Objects
# 1           2017-01-03 10:40:00          RGRTA Passing Stationary Vehicle
# 2           2019-01-22 07:55:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 3           2015-09-22 06:45:00                Collisions w/Other Objects
# 4           2015-04-20 13:14:00                Collisions w/Fixed Objects
# 8           2015-12-01 11:15:00                      Pedestrian collision
# 9           2016-09-16 07:10:00            Vehicle Approaching From Angle
# 10          2015-02-06 14:50:00                Collisions w/Fixed Objects
# 11          2014-10-17 19:24:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 12          2016-10-03 18:02:00  Collisions w/RGRTA vehicles (Bus to Bus)
# 12          2018-03-19 16:58:00                Collisions w/Fixed Objects
# ...

# %%
dfg = rslt_df[['accdate']].groupby('accdate').count()

# %%
dfg
weekdays = ["Sun", "Mon", "Tue", "Wed", "Thu", "Fri", "Sat"]
dfg = dfg.reset_index()
dfg['weekday'] = dfg['accdate'].dt.dayofweek
dfg
week_df = pd.DataFrame(dfg["weekday"].value_counts()).sort_index()
week_df["day"] = weekdays
week_df.columns = ["Accident counts", "Week day"]
week_df
plt.figure(figsize=(12,8))
plt.title('week day counts for preventable accidents')
plt.ylabel('counts', fontsize=12)
plt.xlabel('week day', fontsize=12)
sns.barplot(x="Week day", y="Accident counts", color="orange", data=week_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-affd09c163bb> in <module>
# ----> 1 dfg
#       2 weekdays = ["Sun", "Mon", "Tue", "Wed", "Thu", "Fri", "Sat"]
#       3 dfg = dfg.reset_index()
#       4 dfg['weekday'] = dfg['accdate'].dt.dayofweek
#       5 dfg
#
# NameError: name 'dfg' is not defined

# %%
df_acc_total = df_acc[['accdate']].groupby('accdate').count()
weekdays = ["Sun", "Mon", "Tue", "Wed", "Thu", "Fri", "Sat"]
df_acc_total = df_acc_total.reset_index()
df_acc_total['weekday'] =df_acc_total['accdate'].dt.dayofweek
df_acc_total
week_df_total = pd.DataFrame(df_acc_total["weekday"].value_counts()).sort_index()
week_df_total["day"] = weekdays
week_df_total.columns = ["Accident counts", "Week day"]
week_df_total
plt.figure(figsize=(12,8))
plt.title('week day counts for total accidents')
plt.ylabel('counts', fontsize=12)
plt.xlabel('week day', fontsize=12)
sns.barplot(x="Week day", y="Accident counts", color="orange", data=week_df_total)

# %%
df2
# Out:
#                  accdate  Operator_ID  \
# 0    2014-09-29 15:07:00            1
# 1    2015-03-18 15:29:00            1
# 2    2015-12-08 08:59:00            1
# 3    2016-02-19 13:16:00            1
# 4    2016-04-20 11:46:00            1
# 5    2017-01-03 10:40:00            1
# 6    2018-06-11 11:04:00            1
# 7    2018-09-21 08:07:00            1
# 8    2014-09-19 15:10:00            2
# 9    2015-03-14 10:10:00            2
# 10   2017-05-05 07:22:00            2
# 11   2019-01-22 07:55:00            2
# 12   2015-09-22 06:45:00            3
# 13   2015-03-24 16:40:00            4
# 14   2015-04-20 13:14:00            4
# 15   2015-11-06 17:26:00            4
# 16   2017-09-27 09:44:00            5
# 17   2015-10-15 10:00:00            6
# 18   2014-12-12 16:45:00            7
# 19   2016-10-04 10:22:00            7
# 20   2015-07-13 13:22:00            8
# 21   2015-12-01 11:15:00            8
# 22   2015-01-21 09:24:00            9
# ...

# %%
rslt_df
plt.figure(figsize=(12,8))
df2
sns.stripplot(x='CoDrvSex',y='Drv_Age',hue="AccPreventable",data=df2)

# %%
sns.stripplot(x='CoDrvSex',y='Drv_Age',hue="AccPreventable",data=df2)

# %%
plt.figure(figsize=(12,10))
sns.catplot(x='RoadwayWeather',kind="count",hue="AccPreventable",data=df2)

# %%
plt.figure(figsize=(12,10))
sns.catplot(x='RoadwaySurface',kind="count",hue="AccPreventable",data=df2)

# %%
plt.figure(figsize=(12,10))
sns.catplot(x='RoadwayLightConditions',kind="count",hue="AccPreventable",data=df2)

# %%
plt.figure(figsize=(20,16))


ax=sns.catplot(x='Roadway',kind="count",hue="AccPreventable",data=df2)
ax.set_xticklabels( fontsize=8,rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,16))


ax=sns.catplot(x='vehyear',kind="count",hue="AccPreventable",data=df2)
ax.set_xticklabels( fontsize=8,rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
fi
sns.catplot(x='Absence_Type',kind="count",hue="AccPreventable",data=fi)

# %%
df_prev = pd.read_excel("final_table.xlsx")
df_prev
# Out:
#      Unnamed: 0  Operator_ID  preventable_rate  median_age
# 0             0            1          0.250000        66.0
# 1             5            2          0.250000        70.0
# 2             9            3          1.000000        67.0
# 3            10            4          0.333333        63.0
# 4            13            5          0.000000        66.0
# 5            14            6          0.000000        67.0
# 6            15            7          0.000000        60.5
# 7            17            8          0.500000        55.0
# 8            19            9          0.500000        60.0
# 9            21           10          0.250000        60.5
# 10           25           11          0.200000        66.0
# 11           28           12          0.400000        71.5
# 12           32           13          0.333333        56.0
# 13           35           14          0.000000        56.0
# 14           36           15          0.000000        74.0
# ...

# %%
ss=df_prev[df_prev['preventable_rate']==1]
l_id=list(ss['Operator_ID'])

# %%
sns.lineplot(x="preventable_rate", y="median_age", data=df_prev)

# %%
sns.barplot(x="median_age", y="preventable_rate", data=df_prev)

# %%
sns.lineplot(x="median_age", y="preventable_rate", data=df_prev)

# %%
l=[83, 238, 273, 275, 506, 487, 197, 480, 388, 323, 493, 66, 218, 214, 61]
for i in l_id:
    for j in l:
        if j ==i:
            print(j)
# Out:
# 323
# 480
# 493
# 506
