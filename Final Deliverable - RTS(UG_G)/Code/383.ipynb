# %%
import pandas as pd

# %%
data = pd.read_excel("Master_Accident_Data.xlsx")

# %%
data_timeseg = pd.read_excel("Master_Accident_Data_Timeseg.xlsx")
data_timeseg
# Out:
#         accdate   acctime am/pm  Operator_ID  \
# 0    2016-10-06  01:15:00    AM          149
# 1    2014-11-14  01:15:00    AM          450
# 2    2019-07-24  01:20:00    AM          357
# 3    2018-03-03  01:25:00    AM          472
# 4    2019-02-09  01:27:00    AM          515
# 5    2018-03-06  01:34:00    AM          455
# 6    2015-02-03  01:35:00    AM          143
# 7    2019-04-13  01:40:00    AM          523
# 8    2018-01-26  01:45:00    AM          485
# 9    2017-10-08  01:45:00    AM          512
# 10   2016-08-23  01:45:00    AM          472
# 11   2016-04-29  01:50:00    AM          326
# 12   2017-09-11  02:21:00    AM          497
# 13   2018-02-20  02:38:00    AM          493
# 14   2017-05-23  03:01:00    AM          325
# 15   2018-10-17  03:17:00    AM          367
# 16   2016-10-29  03:22:00    AM          503
# 17   2014-12-09  03:24:00    AM          472
# 18   2016-01-05  03:41:00    AM          470
# 19   2016-03-16  04:03:00    AM          469
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
classbyap = data_timeseg.groupby(['am/pm']).size()
classbyap
# Out:
# am/pm
# AM    502
# PM    812
# dtype: int64

# %%
classbyap.plot.bar()
plt.title('Accident vs. Timesegments')
plt.ylabel('Number of Accidents')
plt.xlabel('Am vs. Pm')
# Out:
# Text(0.5, 0, 'Am vs. Pm')

# %%
Timeslots = ('0~6AM','7~12AM','0~6PM','7~12PM')
Accidents =[109,393,602,210]
plt.bar(Timeslots, Accidents, align='center', alpha=0.8)
plt.title('Accident vs. Timesegments')
plt.ylabel('Number of Accidents')
plt.xlabel('TimeSegments')
# Out:
# Text(0.5, 0, 'TimeSegments')

# %%
classbyWeather = data.groupby(['RoadwayWeather']).size()
classbyWeather
# Out:
# RoadwayWeather
# Clear            706
# Cloudy           226
# Fog                1
# Freezing Rain      6
# Other             24
# Rain              93
# Sleet, Hail        3
# Snow             109
# dtype: int64

# %%
classbyWeather.plot.bar()
plt.title('Accident vs. Weather')
plt.ylabel('Number of Accidents')
plt.xlabel('Weather')
# Out:
# Text(0.5, 0, 'Weather')

# %%
classbySex = data.groupby(['CoDrvSex']).size()
classbySex
# Out:
# CoDrvSex
#        1
# F    313
# M    999
# m      1
# dtype: int64

# %%
classbySex.plot.bar()
plt.title('Accident vs. Sex')
plt.ylabel('Number of Accidents')
plt.xlabel('Sex')
# Out:
# Text(0.5, 0, 'Sex')

# %%
data_acctype = pd.read_excel("Master_Accident_Data_AccType.xlsx")

# %%
classbyAccType = data_acctype.groupby(['acctypecode']).size()
classbyAccType
# Out:
# acctypecode
# 1.0      14
# 2.0      39
# 3.0     896
# 4.0     267
# 5.0       3
# 6.0      61
# 10.0     19
# dtype: int64

# %%
classbyAccType.plot.bar()
plt.title('Accident vs. AccidentType')
plt.ylabel('Number of Accidents')
plt.xlabel('Accident Type Number')
# Out:
# Text(0.5, 0, 'Accident Type Number')

# %%
Preventable1 = 9
NonP1 = 5
Preventable2 = 9
NonP2 = 30
Preventable3 = 553 
NonP3=343
Preventable4 = 239
NonP4 = 28
Preventable5 = 2
NonP5 = 1
Preventable6 = 13
NonP6 = 48
Preventable10 = 10
NonP10 = 9

# %%
classbypreventable = data.groupby(['AccPreventable']).size()
classbypreventable
# Out:
# AccPreventable
# Non-Preventable    678
# Preventable        636
# dtype: int64

# %%
classbypreventable.plot.bar()
plt.title('Accident vs. preventable')
plt.ylabel('Number of Accidents')
plt.xlabel('Preventable vs Nonpreventable')
# Out:
# Text(0.5, 0, 'Preventable vs Nonpreventable')

# %%
classbyap = data_timeseg.groupby(['am/pm']).size()
classbyap
# Out:
# am/pm
# AM    502
# PM    812
# dtype: int64

# %%
classbyap.plot.bar()
plt.title('Accident vs. Timesegments')
plt.ylabel('Number of Accidents')
plt.xlabel('Am vs. Pm')
# Out:
# Text(0.5, 0, 'Am vs. Pm')

# %%
Schooltimes = ('7:30~10AM','10~12AM','3:30~6PM','12~3:30PM')
NUMAccidents =[212,117,225,285]

# %%
plt.bar(Schooltimes, NUMAccidents, align='center', alpha=0.5)
plt.title('Accident vs. School Time')
plt.ylabel('Number of Accidents')
plt.xlabel('School Time')
# Out:
# Text(0.5, 0, 'School Time')

# %%
Seasons = ('Spring','Summer','Fall','Winter')
NumAccidents = [310,307,328,369]
plt.bar(Seasons, NumAccidents, align='center', alpha=0.5)
plt.title('Accident vs. Season')
plt.ylabel('Number of Accidents')
plt.xlabel('Seasons')
# Out:
# Text(0.5, 0, 'Seasons')

# %%
Route1 = pd.read_excel("Route#1.xlsx")
Route1.columns=Route1.iloc[0]
Route1=Route1.drop(Route1.index[0])
Route1
# Out:
# 0    accdate       City  Operator_ID                       AccTypeCodeDescr  \
# 1    8/28/15  Rochester            47                       Vehicle Passing
# 2    1/12/18  Rochester           112  Collisions with other motor vehicles
# 3   11/16/15  Rochester           161        Vehicle Approaching From Angle
# 4   12/20/17  Rochester           171  Collisions with other motor vehicles
# 5     7/7/16  Rochester           168                       Vehicle Passing
# 6    2/12/18  Rochester           309                     Vehicle Following
# 7     1/2/18  Rochester            93  Collisions with other motor vehicles
# 8    6/10/15  Rochester           162  Thrown by movement of RGRTA stopping
# 9   12/22/16  Rochester           375        Vehicle Approaching From Angle
# 10   6/15/17  Rochester           508        Vehicle Approaching From Angle
# 11    8/8/17  Rochester           119  Collisions with other motor vehicles
# ...

# %%
preventable1 = Route1.groupby(Route1['AccPreventable']).size()
preventable1
# Out:
# AccPreventable
# Non-Preventable    13
# Preventable         5
# dtype: int64

# %%
preventable1.plot.bar()
plt.title('Route 1')
plt.ylabel('Number of Accidents')
plt.xlabel('Preventable vs Nonpreventable')
# Out:
# Text(0.5, 0, 'Preventable vs Nonpreventable')

# %%
Route2 = pd.read_excel("Route#2.xlsx")
Route2.columns=Route2.iloc[0]
Route2=Route2.drop(Route2.index[0])
Route2
# Out:
# 0    accdate       City  Operator_ID   \
# 1     7/5/16  Rochester            81
# 2   10/28/17  Rochester           321
# 3    9/13/17  Rochester           361
# 4    1/22/16  Rochester            43
# 5   10/12/17  Rochester           363
# 6    4/24/18  Rochester           192
# 7    4/11/17  Rochester           197
# 8    12/7/16  Rochester            10
# 9     2/3/16  Rochester            76
# 10    2/9/18  Rochester           288
# 11   8/17/16  Rochester            27
# 12   8/26/15  Rochester           134
# 13   1/19/18  Rochester           319
# 14    4/3/18  Rochester           213
# 15    6/9/15  Rochester           193
# 16   3/28/18  Rochester           275
# 17    8/3/16  Rochester            59
# 18   2/19/16  Rochester           281
# 19    9/1/15  Rochester            63
# 20   2/27/17  Rochester            73
# 21   8/23/16  Rochester           174
# 22    2/2/18  Rochester           308
# 23  12/29/17  Rochester           513
# ...

# %%
preventable2 = Route2.groupby(Route2['AccPreventable']).size()
preventable2
# Out:
# AccPreventable
# Non-Preventable    32
# Preventable        20
# dtype: int64

# %%
preventable2.plot.bar()
plt.title('Route 2')
plt.ylabel('Number of Accidents')
plt.xlabel('Preventable vs Nonpreventable')
# Out:
# Text(0.5, 0, 'Preventable vs Nonpreventable')

# %%
Route3 = pd.read_excel("Route#3.xlsx")
Route3.columns=Route3.iloc[0]
Route3=Route3.drop(Route3.index[0])
Route3
# Out:
# 0    accdate       City  Operator_ID   \
# 1    9/29/15  Rochester           113
# 2    5/23/18  Rochester           176
# 3    9/29/14  Rochester           302
# 4    12/3/16  Rochester           237
# 5    2/17/15  Rochester           238
# 6    3/10/15  Rochester            90
# 7     7/2/15  Rochester            50
# 8    6/22/16  Rochester           309
# 9    3/12/18  Rochester           354
# 10   12/6/17  Rochester           357
# 11   9/19/15  Rochester           274
# 12   11/9/16  Rochester           249
# 13  10/15/15  Rochester           308
# 14   5/28/18  Rochester           245
# 15   12/2/14  Rochester            15
# 16   3/17/18  Rochester           331
# 17  11/17/16  Rochester            24
# 18    7/7/16  Rochester            41
# 19   4/18/16  Rochester            94
# 20   5/24/18  Rochester           383
# 21   1/17/18  Rochester           390
# 22   12/5/16  Rochester           276
# 23  12/19/14  Rochester           175
# ...

# %%
preventable3 = Route3.groupby(Route3['AccPreventable']).size()
preventable3
# Out:
# AccPreventable
# Non-Preventable    43
# Preventable        13
# dtype: int64

# %%
preventable3.plot.bar()
plt.title('Route 3')
plt.ylabel('Number of Accidents')
plt.xlabel('Preventable vs Nonpreventable')
# Out:
# Text(0.5, 0, 'Preventable vs Nonpreventable')

# %%
Route4 = pd.read_excel("Route#4.xlsx")
Route4.columns=Route4.iloc[0]
Route4=Route4.drop(Route4.index[0])
Route4
preventable4 = Route4.groupby(Route4['AccPreventable']).size()
preventable4
preventable4.plot.bar()
plt.title('Route 4')
plt.ylabel('Number of Accidents')
plt.xlabel('Preventable vs Nonpreventable')
# Out:
# Text(0.5, 0, 'Preventable vs Nonpreventable')

# %%
Route5 = pd.read_excel("Route#5.xlsx")
Route5.columns=Route5.iloc[0]
Route5=Route5.drop(Route5.index[0])
Route5
preventable5 = Route5.groupby(Route5['AccPreventable']).size()
preventable5
preventable5.plot.bar()
plt.title('Route 5')
plt.ylabel('Number of Accidents')
plt.xlabel('Preventable vs Nonpreventable')
# Out:
# Text(0.5, 0, 'Preventable vs Nonpreventable')

# %%
Route6 = pd.read_excel("Route#6.xlsx")
Route6.columns=Route6.iloc[0]
Route6=Route6.drop(Route6.index[0])
Route6
preventable6 = Route6.groupby(Route6['AccPreventable']).size()
preventable6
preventable6.plot.bar()
plt.title('Route 6')
plt.ylabel('Number of Accidents')
plt.xlabel('Preventable vs Nonpreventable')
# Out:
# Text(0.5, 0, 'Preventable vs Nonpreventable')

# %%
Route7 = pd.read_excel("Route#7.xlsx")
Route7.columns=Route7.iloc[0]
Route7=Route7.drop(Route7.index[0])
Route7
preventable7 = Route7.groupby(Route7['AccPreventable']).size()
preventable7
preventable7.plot.bar()
plt.title('Route 7')
plt.ylabel('Number of Accidents')
plt.xlabel('Preventable vs Nonpreventable')
# Out:
# Text(0.5, 0, 'Preventable vs Nonpreventable')

# %%
Route8 = pd.read_excel("Route#8.xlsx")
Route8.columns=Route8.iloc[0]
Route8=Route8.drop(Route8.index[0])
Route8
preventable8 = Route8.groupby(Route8['AccPreventable']).size()
preventable8
preventable8.plot.bar()
plt.title('Route 8')
plt.ylabel('Number of Accidents')
plt.xlabel('Preventable vs Nonpreventable')
# Out:
# Text(0.5, 0, 'Preventable vs Nonpreventable')

# %%
Route9 = pd.read_excel("Route#9.xlsx")
Route9.columns=Route9.iloc[0]
Route9=Route9.drop(Route9.index[0])
Route9
preventable9 = Route9.groupby(Route9['AccPreventable']).size()
preventable9
preventable9.plot.bar()
plt.title('Route 9')
plt.ylabel('Number of Accidents')
plt.xlabel('Preventable vs Nonpreventable')
# Out:
# Text(0.5, 0, 'Preventable vs Nonpreventable')

# %%
Route10 = pd.read_excel("Route#10.xlsx")
Route10.columns=Route10.iloc[0]
Route10=Route10.drop(Route10.index[0])
Route10
preventable10 = Route10.groupby(Route10['AccPreventable']).size()
preventable10
preventable10.plot.bar()
plt.title('Route 10')
plt.ylabel('Number of Accidents')
plt.xlabel('Preventable vs Nonpreventable')
# Out:
# Text(0.5, 0, 'Preventable vs Nonpreventable')

# %%
Route11 = pd.read_excel("Route#11.xlsx")
Route11.columns=Route11.iloc[0]
Route11=Route11.drop(Route11.index[0])
Route11
preventable11 = Route11.groupby(Route11['AccPreventable']).size()
preventable11
preventable11.plot.bar()
plt.title('Route 11')
plt.ylabel('Number of Accidents')
plt.xlabel('Preventable vs Nonpreventable')
# Out:
# Text(0.5, 0, 'Preventable vs Nonpreventable')

# %%
Route12 = pd.read_excel("Route#12.xlsx")
Route12.columns=Route12.iloc[0]
Route12=Route12.drop(Route12.index[0])
Route12
preventable12 = Route12.groupby(Route12['AccPreventable']).size()
preventable12
preventable12.plot.bar()
plt.title('Route 12')
plt.ylabel('Number of Accidents')
plt.xlabel('Preventable vs Nonpreventable')
# Out:
# Text(0.5, 0, 'Preventable vs Nonpreventable')

# %%
Route13 = pd.read_excel("Route#13.xlsx")
Route13.columns=Route13.iloc[0]
Route13=Route13.drop(Route13.index[0])
Route13
preventable13 = Route13.groupby(Route13['AccPreventable']).size()
preventable13
preventable13.plot.bar()
plt.title('Route 13')
plt.ylabel('Number of Accidents')
plt.xlabel('Preventable vs Nonpreventable')
# Out:
# Text(0.5, 0, 'Preventable vs Nonpreventable')

# %%
Jefferson = pd.read_excel("JeffersonAve.xlsx")
Jefferson.columns=Jefferson.iloc[0]
Jefferson=Jefferson.drop(Jefferson.index[0])
Jefferson
preventableJeff = Jefferson.groupby(Jefferson['AccPreventable']).size()
preventableJeff
# Out:
# AccPreventable
# Non-Preventable    4
# Preventable        8
# dtype: int64

# %%
non =['non-preventable','preventable']
colors = ['orange', 'pink']
plt.pie(preventableJeff, labels=non, colors=colors, startangle=90, autopct='%.1f%%')
plt.title('Jefferson Ave')
plt.show()

# %%
Walmart = pd.read_excel("Walmart.xlsx")
Walmart.columns=Walmart.iloc[0]
Walmart=Walmart.drop(Walmart.index[0])
Walmart
preventableWal = Walmart.groupby(Walmart['AccPreventable']).size()
preventableWal
# Out:
# AccPreventable
# Non-Preventable     2
# Preventable        11
# dtype: int64

# %%
plt.pie(preventableWal, labels=non, colors=colors, startangle=90, autopct='%.1f%%')
plt.title('Walmart')
plt.show()

# %%
Hospital = pd.read_excel("Hospital.xlsx")
Hospital.columns=Hospital.iloc[0]
Hospital=Hospital.drop(Hospital.index[0])
Hospital
preventableHos = Hospital.groupby(Hospital['AccPreventable']).size()
preventableHos
# Out:
# AccPreventable
# Non-Preventable    11
# Preventable        11
# dtype: int64

# %%
plt.pie(preventableHos, labels=non, colors=colors, startangle=90, autopct='%.1f%%')
plt.title('Strong Memorial Hospital')
plt.show()

# %%
Routes_time = pd.read_excel("Routes_time.xlsx")
Routes_time.columns=Routes_time.iloc[0]
Routes_time=Routes_time.drop(Routes_time.index[0])
Routes_time
route_preventable = Routes_time.groupby(['RouteNum','AccPreventable']).size().unstack('AccPreventable').fillna(0)
route_preventable.plot(kind='bar', stacked=True)

# %%
route_acctype = Routes_time.groupby(['RouteNum','acctype']).size().unstack('acctype').fillna(0)
route_acctype.plot(kind='bar', stacked=True)

# %%
Route_preventable=Routes_time[Routes_time['AccPreventable']=='Preventable']
Route_preventable
# Out:
# 0     accdate       City  Operator_ID   \
# 9    12/22/16  Rochester           375
# 14    8/27/14  Rochester            61
# 15    5/21/18  Rochester           254
# 17   10/17/16  Rochester           205
# 18    10/6/15  Rochester           251
# 19     7/5/16  Rochester            81
# 23   10/12/17  Rochester           363
# 36    2/19/16  Rochester           281
# 39    8/23/16  Rochester           174
# 41   12/29/17  Rochester           513
# 42    4/16/17  Rochester           356
# 44    3/25/15  Rochester            22
# 45    7/31/17  Rochester            18
# 46   12/27/14  Rochester           186
# 47    9/17/15  Rochester           323
# 48    11/1/16  Rochester           365
# 50    8/18/15  Rochester           165
# 51    8/28/14  Rochester           172
# 58   12/19/15  Rochester           119
# 60    9/28/17  Rochester           178
# 61    6/25/18  Rochester           275
# 63    6/19/17  Rochester            69
# 65    4/26/16  Rochester           146
# ...

# %%
route_acctype_pre = Route_preventable.groupby(['RouteNum','acctype']).size().unstack('acctype').fillna(0)
route_acctype_pre.plot(kind='bar', stacked=True)
