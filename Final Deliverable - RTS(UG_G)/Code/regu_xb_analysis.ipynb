# %%
import pandas 
import pandas as pd


df = pd.read_excel("Master_Scheduled_Days_Off.xlsx")

df_scheduled=df.set_index('Operator_ID')
df_scheduled.head()
df2 = pd.read_excel("Master_Accident_Data.xlsx")

df_acc=df2.set_index('Operator_ID')
df_acc.head()
# Out:
#                         accdate            AccTypeCodeDescr  \
# Operator_ID
# 1           2014-09-29 15:07:00  Collisions w/Other Objects
# 1           2015-03-18 15:29:00             Vehicle Passing
# 1           2015-12-08 08:59:00             Vehicle Passing
# 1           2016-02-19 13:16:00             Vehicle Passing
# 1           2016-04-20 11:46:00             Vehicle Passing
#
#                                          AccSubTypeCodeDescr  \
# Operator_ID
# 1                     Fixed object (lamp posts, poles, etc.)
# 1             Vehicle cuts in and scrapes RGRTA on left side
# 1             Vehicle cuts in and scrapes RGRTA on left side
# 1             Vehicle cuts in and scrapes RGRTA on left side
# 1            Vehicle cuts in and scrapes RGRTA on right side
#
#                                 acctype BAITFISH Code FileNumber  \
# Operator_ID
# 1            04 - MVA with Fixed Object  Fixed Object    14-1043
# ...

# %%
df = pd.read_excel("Master_Scheduled_Days_Off.xlsx")

df_scheduled=df.set_index('Operator_ID')
df_scheduled
# Out:
#             Effective_On No_Longer_Effective_After Pick_Name Seniority_Date  \
# Operator_ID
# 1             2016-04-04                2016-06-26   APR2016     06-20-1974
# 2             2016-04-04                2016-06-26   APR2016     08-22-1974
# 3             2016-04-04                2016-06-26   APR2016     06-22-1977
# 5             2016-04-04                2016-06-26   APR2016     08-03-1977
# 6             2016-04-04                2016-06-26   APR2016     02-04-1980
# 7             2016-04-04                2016-06-26   APR2016     08-18-1980
# 8             2016-04-04                2016-06-26   APR2016     10-15-1983
# 9             2016-04-04                2016-06-26   APR2016     02-06-1982
# 10            2016-04-04                2016-06-26   APR2016     05-29-1982
# 11            2016-04-04                2016-06-26   APR2016     07-25-1983
# 12            2016-04-04                2016-06-26   APR2016     07-27-1983
# ...

# %%
df2 = pd.read_excel("Master_Accident_Data.xlsx")

df_acc=df2.set_index('Operator_ID')
df_acc
# Out:
#                         accdate                          AccTypeCodeDescr  \
# Operator_ID
# 1           2014-09-29 15:07:00                Collisions w/Other Objects
# 1           2015-03-18 15:29:00                           Vehicle Passing
# 1           2015-12-08 08:59:00                           Vehicle Passing
# 1           2016-02-19 13:16:00                           Vehicle Passing
# 1           2016-04-20 11:46:00                           Vehicle Passing
# 1           2017-01-03 10:40:00          RGRTA Passing Stationary Vehicle
# 1           2018-06-11 11:04:00      Collisions with other motor vehicles
# 1           2018-09-21 08:07:00      Collisions with other motor vehicles
# 2           2014-09-19 15:10:00                           Vehicle Passing
# 2           2015-03-14 10:10:00                           Vehicle Passing
# 2           2017-05-05 07:22:00                Collisions w/Fixed Objects
# ...

# %%
df_scheduled.head()
# Out:
#             Effective_On No_Longer_Effective_After Pick_Name Seniority_Date  \
# Operator_ID
# 1             2016-04-04                2016-06-26   APR2016     06-20-1974
# 2             2016-04-04                2016-06-26   APR2016     08-22-1974
# 3             2016-04-04                2016-06-26   APR2016     06-22-1977
# 5             2016-04-04                2016-06-26   APR2016     08-03-1977
# 6             2016-04-04                2016-06-26   APR2016     02-04-1980
#
#               Sun  Mon  Tue  Wed  Thu  Fri   Sat Type_Work
# Operator_ID
# 1             OFF  NaN  NaN  NaN  NaN  NaN   OFF   REGULAR
# 2             OFF  NaN  NaN  NaN  NaN  NaN   OFF        XB
# 3             OFF  NaN  NaN  NaN  NaN  NaN   OFF   REGULAR
# 5             OFF  NaN  NaN  NaN  NaN  NaN   OFF   REGULAR
# 6             OFF  NaN  NaN  NaN  NaN  NaN   OFF        XB

# %%
resultzz = df_acc.join(df_scheduled, how='outer')

# %%
resultzz
# Out:
#                         accdate                          AccTypeCodeDescr  \
# Operator_ID
# 1           2014-09-29 15:07:00                Collisions w/Other Objects
# 1           2014-09-29 15:07:00                Collisions w/Other Objects
# 1           2014-09-29 15:07:00                Collisions w/Other Objects
# 1           2014-09-29 15:07:00                Collisions w/Other Objects
# 1           2014-09-29 15:07:00                Collisions w/Other Objects
# 1           2014-09-29 15:07:00                Collisions w/Other Objects
# 1           2014-09-29 15:07:00                Collisions w/Other Objects
# 1           2014-09-29 15:07:00                Collisions w/Other Objects
# 1           2014-09-29 15:07:00                Collisions w/Other Objects
# 1           2014-09-29 15:07:00                Collisions w/Other Objects
# 1           2014-09-29 15:07:00                Collisions w/Other Objects
# ...

# %%
resultzz['Operator_ID']=resultzz.index()
resultzz
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-4cf0cc6f876a> in <module>
# ----> 1 resultzz['Operator_ID']=resultzz.index()
#       2 resultzz
#
# TypeError: 'Int64Index' object is not callable

# %%
# if start <= date <= end:
#     print('yes')
# else:
#     print('no')
    
fi=pd.DataFrame()    
dds=resultzz
count=0
# row['Effective_On']<=
for index, row in dds.iterrows():
    if  row['Effective_On']<= row['accdate'] <= row['No_Longer_Effective_After']:
#         ls=dds.index[index]
        continue
    else:
        try:
            dds.drop(dds.index[index], inplace=True)
        except:
            print()
            
        
        
    
    
print(count)
# Out:
# 0

# %%
dds
# Out:
#        index  Operator_ID             accdate  \
# 1          1            1 2014-09-29 15:07:00
# 3          3            1 2014-09-29 15:07:00
# 5          5            1 2014-09-29 15:07:00
# 7          7            1 2014-09-29 15:07:00
# 9          9            1 2014-09-29 15:07:00
# 11        11            1 2014-09-29 15:07:00
# 13        13            1 2014-09-29 15:07:00
# 15        15            1 2015-03-18 15:29:00
# 17        17            1 2015-03-18 15:29:00
# 19        19            1 2015-03-18 15:29:00
# 21        21            1 2015-03-18 15:29:00
# 23        23            1 2015-03-18 15:29:00
# 25        25            1 2015-03-18 15:29:00
# 27        27            1 2015-03-18 15:29:00
# 29        29            1 2015-12-08 08:59:00
# 31        31            1 2015-12-08 08:59:00
# 33        33            1 2015-12-08 08:59:00
# 35        35            1 2015-12-08 08:59:00
# 37        37            1 2015-12-08 08:59:00
# ...

# %%
resultzz.reset_index(inplace=True)
resultzz
# Out:
#        index  Operator_ID             accdate  \
# 0          0            1 2014-09-29 15:07:00
# 1          1            1 2014-09-29 15:07:00
# 2          2            1 2014-09-29 15:07:00
# 3          3            1 2014-09-29 15:07:00
# 4          4            1 2014-09-29 15:07:00
# 5          5            1 2014-09-29 15:07:00
# 6          6            1 2014-09-29 15:07:00
# 7          7            1 2014-09-29 15:07:00
# 8          8            1 2014-09-29 15:07:00
# 9          9            1 2014-09-29 15:07:00
# 10        10            1 2014-09-29 15:07:00
# 11        11            1 2014-09-29 15:07:00
# 12        12            1 2014-09-29 15:07:00
# 13        13            1 2014-09-29 15:07:00
# 14        14            1 2015-03-18 15:29:00
# 15        15            1 2015-03-18 15:29:00
# 16        16            1 2015-03-18 15:29:00
# 17        17            1 2015-03-18 15:29:00
# 18        18            1 2015-03-18 15:29:00
# ...

# %%
dds
# Out:
#        index  Operator_ID             accdate  \
# 1          1            1 2014-09-29 15:07:00
# 3          3            1 2014-09-29 15:07:00
# 5          5            1 2014-09-29 15:07:00
# 7          7            1 2014-09-29 15:07:00
# 9          9            1 2014-09-29 15:07:00
# 11        11            1 2014-09-29 15:07:00
# 13        13            1 2014-09-29 15:07:00
# 15        15            1 2015-03-18 15:29:00
# 17        17            1 2015-03-18 15:29:00
# 19        19            1 2015-03-18 15:29:00
# 21        21            1 2015-03-18 15:29:00
# 23        23            1 2015-03-18 15:29:00
# 25        25            1 2015-03-18 15:29:00
# 27        27            1 2015-03-18 15:29:00
# 29        29            1 2015-12-08 08:59:00
# 31        31            1 2015-12-08 08:59:00
# 33        33            1 2015-12-08 08:59:00
# 35        35            1 2015-12-08 08:59:00
# 37        37            1 2015-12-08 08:59:00
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,10))
sns.catplot(x='Type_Work',kind="count",hue="AccPreventable",data=dds)

# %%
duplicate_dds=resultzz
for index, row in duplicate_dds.iterrows():
    if  row['Effective_On']<= row['accdate'] <= row['No_Longer_Effective_After']:
#         ls=dds.index[index]
        continue
    else:
        try:
            dds.drop(dds.index[index], inplace=True)
        except:
            print()

# %%
resultzz
# Out:
#        index  Operator_ID             accdate  \
# 165      165            3 2015-09-22 06:45:00
# 167      167            4 2015-04-20 13:14:00
# 177      177            6 2015-10-15 10:00:00
# 363      363           14 2015-06-08 14:06:00
# 365      365           15 2014-12-02 09:15:00
# 623      623           25                 NaT
# 1369    1369           49 2015-12-17 08:00:00
# 2724    2724           78 2014-11-18 07:17:00
# 3300    3300           89 2014-12-04 09:51:00
# 3302    3302           90 2015-03-10 06:56:00
# 3304    3304           91 2015-04-27 16:30:00
# 3510    3510          100 2014-08-20 09:14:00
# 4967    4967          135 2015-07-27 08:20:00
# 5026    5026          138                 NaT
# 5163    5163          143 2015-02-03 01:35:00
# 5540    5540          155 2016-01-13 14:59:00
# 5738    5738          159 2015-02-20 08:05:00
# 7999    7999          215                 NaT
# 9874    9874          259 2014-08-14 18:55:00
# ...

# %%
resultzz.reset_index(inplace=True) 


duplica_two=resultzz

  
# dropping ALL duplicte values 
dfdup=duplica_two.drop_duplicates(subset ="accdate", keep = 'first') 
  
# displaying data 
dfdup
# Out:
#        level_0  index  Operator_ID             accdate  \
# 0            0      0            1 2014-09-29 15:07:00
# 112        112    112            2 2014-09-19 15:10:00
# 164        164    164            3 2015-09-22 06:45:00
# 166        166    166            4 2015-03-24 16:40:00
# 169        169    169            5 2017-09-27 09:44:00
# 176        176    176            6 2015-10-15 10:00:00
# 178        178    178            7 2014-12-12 16:45:00
# 184        184    184            8 2015-07-13 13:22:00
# 190        190    190            9 2015-01-21 09:24:00
# 200        200    200           10 2015-02-06 14:50:00
# 256        256    256           11 2014-10-17 19:24:00
# 266        266    266           12 2016-10-03 18:02:00
# 321        321    321           13 2014-11-21 12:55:00
# 363        363    363           14 2015-06-08 14:06:00
# 365        365    365           15 2014-12-02 09:15:00
# 366        366    366           16 2014-12-02 13:00:00
# ...

# %%
plt.figure(figsize=(12,10))
sns.catplot(x='Type_Work',kind="count",hue="AccPreventable",data=dfdup)

# %%
duplica_three=resultzz
dfdup2=duplica_three.drop_duplicates(subset ="accdate", keep = 'first') 
  
# displaying data 
dfdup2
# Out:
#        level_0  index  Operator_ID             accdate  \
# 0            0      0            1 2014-09-29 15:07:00
# 14          14     14            1 2015-03-18 15:29:00
# 28          28     28            1 2015-12-08 08:59:00
# 42          42     42            1 2016-02-19 13:16:00
# 56          56     56            1 2016-04-20 11:46:00
# 70          70     70            1 2017-01-03 10:40:00
# 84          84     84            1 2018-06-11 11:04:00
# 98          98     98            1 2018-09-21 08:07:00
# 112        112    112            2 2014-09-19 15:10:00
# 125        125    125            2 2015-03-14 10:10:00
# 138        138    138            2 2017-05-05 07:22:00
# 151        151    151            2 2019-01-22 07:55:00
# 164        164    164            3 2015-09-22 06:45:00
# 166        166    166            4 2015-03-24 16:40:00
# 167        167    167            4 2015-04-20 13:14:00
# 168        168    168            4 2015-11-06 17:26:00
# ...

# %%
plt.figure(figsize=(12,10))
sns.catplot(x='Type_Work',kind="count",hue="AccPreventable",data=dfdup2)

# %%
pre_acc=dfdup2[dfdup2[AccPreventable]=='Preventable']
sns.catplot(x='Type_Work',kind="count",hue="AccPreventable",data=pre_acc)
